# %%
from keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(rescale=1./255,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   horizontal_flip=True)
test_datagen=ImageDataGenerator(rescale=1./255)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/unzipped_data
# !unzip '/content/drive/MyDrive/CancerVision/CancerDataset/Mammo_img_dataset.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: IDC_regular_ps50_idx5/9346/0/9346_idx5_x2351_y1551_class0.png
#   inflating: IDC_regular_ps50_idx5/9346/0/9346_idx5_x2351_y1601_class0.png
#   inflating: IDC_regular_ps50_idx5/9346/0/9346_idx5_x2351_y1651_class0.png
#   inflating: IDC_regular_ps50_idx5/9346/0/9346_idx5_x2351_y1701_class0.png
#   inflating: IDC_regular_ps50_idx5/9346/0/9346_idx5_x2351_y1751_class0.png
#   inflating: IDC_regular_ps50_idx5/9346/0/9346_idx5_x2351_y1801_class0.png
#   inflating: IDC_regular_ps50_idx5/9346/0/9346_idx5_x2351_y1851_class0.png
#   inflating: IDC_regular_ps50_idx5/9346/0/9346_idx5_x2351_y1901_class0.png
#   inflating: IDC_regular_ps50_idx5/9346/0/9346_idx5_x2351_y1951_class0.png
#   inflating: IDC_regular_ps50_idx5/9346/0/9346_idx5_x2351_y2001_class0.png
#   inflating: IDC_regular_ps50_idx5/9346/0/9346_idx5_x2351_y2251_class0.png
#   inflating: IDC_regular_ps50_idx5/9346/0/9346_idx5_x2351_y2301_class0.png
# ...

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Flatten
from keras.layers import MaxPooling2D

# %%
# !pip install split-folders
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import splitfolders

# %%
model = Sequential()

# %%
model.add(Conv2D (64, (3, 3), activation='relu', input_shape=(75, 75, 3)))

# %%
model.add(MaxPooling2D(pool_size = (2,2)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fafd2ae2a761> in <cell line: 1>()
# ----> 1 model.add(MaxPooling2D(pool_size = (2,2)))
#
# NameError: name 'model' is not defined

# %%
model.add(Flatten())

# %%
model.add(Dense(units=40, activation='relu', input_shape=(75, 75, 3)))
model.add(Dense(units=1, activation='sigmoid'))

# %%
model.compile(loss="binary_crossentropy", optimizer="adam",metrics=["accuracy"])

# %%
# Out:
# Found 227 images belonging to 2 classes.
# Found 557 images belonging to 2 classes.
# Found 1623 images belonging to 2 classes.
# Found 1202 images belonging to 2 classes.
# Found 1289 images belonging to 2 classes.
# Found 1652 images belonging to 2 classes.
# Found 1904 images belonging to 2 classes.
# Found 392 images belonging to 2 classes.
# Found 986 images belonging to 2 classes.
# Found 312 images belonging to 2 classes.
# Found 955 images belonging to 2 classes.
# Found 829 images belonging to 2 classes.
# Found 356 images belonging to 2 classes.
# Found 1505 images belonging to 2 classes.
# Found 1907 images belonging to 2 classes.
# Found 407 images belonging to 2 classes.
# Found 1485 images belonging to 2 classes.
# Found 182 images belonging to 2 classes.
# Found 1781 images belonging to 2 classes.
# Found 2106 images belonging to 2 classes.
# Found 586 images belonging to 2 classes.
# Found 1935 images belonging to 2 classes.
# ...

# %%
model.fit(train_generator, batch_size=32, epochs=25, steps_per_epoch=len(train_generator) ,validation_data=(test_generator))
# Out:
# Epoch 1/25
# 18/18 [==============================] - 5s 273ms/step - loss: 0.6047 - accuracy: 0.1275 - val_loss: 0.0548 - val_accuracy: 0.0625
# Epoch 2/25
# 18/18 [==============================] - 6s 337ms/step - loss: 0.3205 - accuracy: 0.1275 - val_loss: 0.0572 - val_accuracy: 0.0625
# Epoch 3/25
# 18/18 [==============================] - 4s 215ms/step - loss: 0.2719 - accuracy: 0.1275 - val_loss: 0.0682 - val_accuracy: 0.0625
# Epoch 4/25
# 18/18 [==============================] - 6s 328ms/step - loss: 0.2386 - accuracy: 0.1275 - val_loss: 0.0610 - val_accuracy: 0.0625
# Epoch 5/25
# 18/18 [==============================] - 4s 247ms/step - loss: 0.2077 - accuracy: 0.1275 - val_loss: 0.0564 - val_accuracy: 0.0625
# Epoch 6/25
# 18/18 [==============================] - 5s 273ms/step - loss: 0.1843 - accuracy: 0.1275 - val_loss: 0.0469 - val_accuracy: 0.0625
# Epoch 7/25
# ...

# %%
model.save('Breast_cancer_detection.h5')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-b431c0c3566d> in <cell line: 1>()
# ----> 1 model.save('Breast_cancer_detection.h5')
#
# NameError: name 'model' is not defined

# %%
from keras.models import load_model
import keras.utils as image
#from keras.preprocessing import image
import numpy as np
model = load_model('/content/unzipped_data/Breast_cancer_detection.h5')
img_path = '/content/unzipped_data/9325/0/9325_idx5_x1001_y1201_class0.png'
img = image.load_img(img_path, target_size=(75, 75))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = x / 255.0  # Normalize pixel values to the range of 0-1
predictions = model.predict(x)
predictions
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-4-cd056d7a5f32> in <cell line: 5>()
#       3 #from keras.preprocessing import image
#       4 import numpy as np
# ----> 5 model = load_model('/content/unzipped_data/Breast_cancer_detection.h5')
#       6 img_path = '/content/unzipped_data/9325/0/9325_idx5_x1001_y1201_class0.png'
#       7 img = image.load_img(img_path, target_size=(75, 75))
#
# /usr/local/lib/python3.10/dist-packages/keras/saving/saving_api.py in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     210
#     211     # Legacy case.
# --> 212     return legacy_sm_saving_lib.load_model(
#     213         filepath, custom_objects=custom_objects, compile=compile, **kwargs
#     214     )
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
# ...

# %%
if predictions[0]== 1:
  result = 'malignant'
else :
  result = 'benign'
